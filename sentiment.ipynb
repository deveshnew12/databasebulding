# %%
from textblob import TextBlob
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("drugsComTest_raw.csv")
df=pd.DataFrame(df)
df
# Out:
#          D_id         drugName  ... usefulCount  review.1
# 0         d10      Mirtazapine  ...          22  positive
# 1         d11       Mesalamine  ...          17  positive
# 2         d12          Bactrim  ...           3  positive
# 3         d13         Contrave  ...          35  positive
# 4         d14  Cyclafem 1 / 35  ...           4  positive
# ...       ...              ...  ...         ...       ...
# 53761  d53771        Tamoxifen  ...          43  positive
# 53762  d53772     Escitalopram  ...          11  positive
# 53763  d53773   Levonorgestrel  ...           7  positive
# 53764  d53774       Tapentadol  ...          20  negative
# 53765  d53775        Arthrotec  ...          46  positive
#
# [53766 rows x 8 columns]

# %%
review=df['review']

# %%
positive=0
negative=0
neutral=0
rev=[]
for r in review:
  analysis=TextBlob(r)
  print(analysis.sentiment)
  if analysis.sentiment.polarity>0:
    print("positive")
    rev.append('positive')
    positive=positive+1
  elif analysis.sentiment.polarity==0:
    print("neutral") 
    rev.append('neutral')
    neutral=neutral+1
  else:
     print("negative")
     rev.append('negative')
     negative=negative+1
# Out:
# Streaming output truncated to the last 5000 lines.
# Sentiment(polarity=-0.029999999999999992, subjectivity=0.5233333333333333)
# negative
# Sentiment(polarity=0.1695436507936508, subjectivity=0.5301587301587302)
# positive
# Sentiment(polarity=0.29619047619047617, subjectivity=0.5197619047619048)
# positive
# Sentiment(polarity=0.175, subjectivity=0.6516666666666666)
# positive
# Sentiment(polarity=-0.32526455026455026, subjectivity=0.44960317460317456)
# negative
# Sentiment(polarity=-0.225, subjectivity=0.4)
# negative
# Sentiment(polarity=0.21863636363636366, subjectivity=0.3987878787878788)
# positive
# Sentiment(polarity=0.004095238095238096, subjectivity=0.4169761904761905)
# positive
# Sentiment(polarity=0.056249999999999994, subjectivity=0.43125)
# positive
# Sentiment(polarity=0.018750000000000003, subjectivity=0.5125)
# positive
# Sentiment(polarity=-0.13020833333333334, subjectivity=0.5788194444444446)
# negative
# Sentiment(polarity=0.08896103896103896, subjectivity=0.5467532467532469)
# positive
# Sentiment(polarity=0.0597979797979798, subjectivity=0.47777777777777775)
# positive
# Sentiment(polarity=0.16574074074074074, subjectivity=0.32037037037037036)
# positive
# Sentiment(polarity=0.147, subjectivity=0.518)
# positive
# Sentiment(polarity=-0.015625, subjectivity=0.47361111111111115)
# negative
# Sentiment(polarity=0.04166666666666668, subjectivity=0.47500000000000003)
# positive
# Sentiment(polarity=-0.0767857142857143, subjectivity=0.48095238095238096)
# negative
# Sentiment(polarity=0.04230769230769231, subjectivity=0.28540433925049313)
# positive
# Sentiment(polarity=0.06666666666666668, subjectivity=0.45185185185185184)
# positive
# Sentiment(polarity=0.2907407407407408, subjectivity=0.6485185185185185)
# positive
# Sentiment(polarity=-0.08194444444444444, subjectivity=0.48611111111111116)
# negative
# Sentiment(polarity=-0.0025000000000000022, subjectivity=0.4098809523809524)
# negative
# Sentiment(polarity=0.1111111111111111, subjectivity=0.3927248677248677)
# positive
# Sentiment(polarity=0.00477777777777779, subjectivity=0.40299999999999997)
# positive
# Sentiment(polarity=-0.24375000000000002, subjectivity=0.65)
# negative
# Sentiment(polarity=0.4136904761904762, subjectivity=0.7714285714285714)
# positive
# Sentiment(polarity=-0.18958333333333333, subjectivity=0.5625)
# negative
# Sentiment(polarity=-0.019191919191919194, subjectivity=0.3253787878787879)
# negative
# Sentiment(polarity=0.05416666666666666, subjectivity=0.47500000000000003)
# positive
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=-0.10499999999999998, subjectivity=0.5891666666666667)
# negative
# Sentiment(polarity=0.04362980769230769, subjectivity=0.37151442307692306)
# positive
# Sentiment(polarity=0.3375, subjectivity=0.4083333333333333)
# positive
# Sentiment(polarity=0.05133928571428572, subjectivity=0.5419642857142857)
# positive
# Sentiment(polarity=-0.037500000000000006, subjectivity=0.6270833333333333)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5499999999999999)
# positive
# Sentiment(polarity=0.29215909090909087, subjectivity=0.4969318181818182)
# positive
# Sentiment(polarity=-0.022402597402597396, subjectivity=0.3515984015984016)
# negative
# Sentiment(polarity=-0.09499999999999999, subjectivity=0.5700000000000001)
# negative
# Sentiment(polarity=0.1523809523809524, subjectivity=0.20892857142857144)
# positive
# Sentiment(polarity=-0.1181818181818182, subjectivity=0.7113636363636363)
# negative
# Sentiment(polarity=0.10833333333333335, subjectivity=0.5194444444444444)
# positive
# Sentiment(polarity=0.16916666666666666, subjectivity=0.5583333333333335)
# positive
# Sentiment(polarity=0.22499999999999998, subjectivity=0.325)
# positive
# Sentiment(polarity=0.5, subjectivity=0.8333333333333334)
# positive
# Sentiment(polarity=0.08812500000000004, subjectivity=0.49416666666666664)
# positive
# Sentiment(polarity=-0.045454545454545435, subjectivity=0.5356060606060605)
# negative
# Sentiment(polarity=0.125, subjectivity=0.4401515151515152)
# positive
# Sentiment(polarity=-0.0011363636363636222, subjectivity=0.5348484848484847)
# negative
# Sentiment(polarity=0.12272727272727274, subjectivity=0.4462121212121212)
# positive
# Sentiment(polarity=0.28125, subjectivity=0.6916666666666668)
# positive
# Sentiment(polarity=1.0, subjectivity=0.75)
# positive
# Sentiment(polarity=0.11631944444444445, subjectivity=0.6305555555555554)
# positive
# Sentiment(polarity=0.06267857142857144, subjectivity=0.43285714285714283)
# positive
# Sentiment(polarity=0.30833333333333335, subjectivity=0.44999999999999996)
# positive
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# Sentiment(polarity=0.09375, subjectivity=0.515625)
# positive
# Sentiment(polarity=0.020833333333333363, subjectivity=0.39166666666666666)
# positive
# Sentiment(polarity=0.2833333333333333, subjectivity=0.6436507936507937)
# positive
# Sentiment(polarity=0.35761904761904767, subjectivity=0.4751190476190476)
# positive
# Sentiment(polarity=0.22999999999999998, subjectivity=0.5466666666666666)
# positive
# Sentiment(polarity=0.0923611111111111, subjectivity=0.4833333333333334)
# positive
# Sentiment(polarity=0.13333333333333333, subjectivity=0.5423611111111111)
# positive
# Sentiment(polarity=0.125, subjectivity=0.2875)
# positive
# Sentiment(polarity=-0.031944444444444414, subjectivity=0.5629629629629629)
# negative
# Sentiment(polarity=-0.016666666666666656, subjectivity=0.4470238095238095)
# negative
# Sentiment(polarity=0.31606060606060604, subjectivity=0.44909090909090904)
# positive
# Sentiment(polarity=-0.12333333333333334, subjectivity=0.4693589743589744)
# negative
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
# Sentiment(polarity=-0.0782051282051282, subjectivity=0.4769230769230768)
# negative
# Sentiment(polarity=-0.12439393939393939, subjectivity=0.4592424242424243)
# negative
# Sentiment(polarity=-0.28125, subjectivity=1.0)
# negative
# Sentiment(polarity=0.19166666666666665, subjectivity=0.4444444444444444)
# positive
# Sentiment(polarity=0.023076923076923085, subjectivity=0.5019230769230769)
# positive
# Sentiment(polarity=-0.13974358974358972, subjectivity=0.4955128205128204)
# negative
# Sentiment(polarity=0.15824074074074074, subjectivity=0.38814814814814813)
# positive
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.39999999999999997)
# negative
# Sentiment(polarity=-0.10995179063360881, subjectivity=0.634090909090909)
# negative
# Sentiment(polarity=-0.011833333333333328, subjectivity=0.40437500000000004)
# negative
# Sentiment(polarity=0.09888888888888889, subjectivity=0.3377777777777778)
# positive
# Sentiment(polarity=-0.2029761904761905, subjectivity=0.44431216931216927)
# negative
# Sentiment(polarity=0.8, subjectivity=0.75)
# positive
# Sentiment(polarity=0.057083333333333354, subjectivity=0.39595238095238094)
# positive
# Sentiment(polarity=-0.03749999999999999, subjectivity=0.35833333333333334)
# negative
# Sentiment(polarity=-0.025, subjectivity=0.625)
# negative
# Sentiment(polarity=0.11091269841269841, subjectivity=0.38239087301587305)
# positive
# Sentiment(polarity=-0.23095238095238094, subjectivity=0.4294642857142857)
# negative
# Sentiment(polarity=-0.08022222222222222, subjectivity=0.5235555555555556)
# negative
# Sentiment(polarity=0.0643939393939394, subjectivity=0.4840909090909091)
# positive
# Sentiment(polarity=0.03044871794871797, subjectivity=0.6698717948717949)
# positive
# Sentiment(polarity=-0.06909722222222221, subjectivity=0.5170138888888889)
# negative
# Sentiment(polarity=-0.009259259259259264, subjectivity=0.48518518518518516)
# negative
# Sentiment(polarity=0.012500000000000002, subjectivity=0.5736111111111111)
# positive
# Sentiment(polarity=0.08271604938271604, subjectivity=0.5376543209876543)
# positive
# Sentiment(polarity=-0.12777777777777777, subjectivity=0.7999999999999999)
# negative
# Sentiment(polarity=0.13333333333333333, subjectivity=0.63125)
# positive
# Sentiment(polarity=0.13939393939393938, subjectivity=0.4075757575757576)
# positive
# Sentiment(polarity=0.054166666666666675, subjectivity=0.34270833333333334)
# positive
# Sentiment(polarity=0.1388888888888889, subjectivity=0.34111111111111114)
# positive
# Sentiment(polarity=0.03333333333333335, subjectivity=0.3666666666666667)
# positive
# Sentiment(polarity=-0.12000000000000002, subjectivity=0.72)
# negative
# Sentiment(polarity=-0.03928571428571428, subjectivity=0.34404761904761905)
# negative
# Sentiment(polarity=-0.006663860830527443, subjectivity=0.49450056116722774)
# negative
# Sentiment(polarity=-0.1120982142857143, subjectivity=0.4688541666666667)
# negative
# Sentiment(polarity=0.2116391184573003, subjectivity=0.5504132231404959)
# positive
# Sentiment(polarity=0.0022222222222222144, subjectivity=0.38634920634920633)
# positive
# Sentiment(polarity=0.1702991452991453, subjectivity=0.5581196581196581)
# positive
# Sentiment(polarity=0.08181818181818183, subjectivity=0.4651515151515152)
# positive
# Sentiment(polarity=0.027621527777777787, subjectivity=0.5080555555555556)
# positive
# Sentiment(polarity=-0.009722222222222224, subjectivity=0.175)
# negative
# Sentiment(polarity=0.15822222222222224, subjectivity=0.5559999999999999)
# positive
# Sentiment(polarity=-0.10833333333333334, subjectivity=0.5138888888888888)
# negative
# Sentiment(polarity=0.005555555555555545, subjectivity=0.2888888888888889)
# positive
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# Sentiment(polarity=0.08750000000000002, subjectivity=0.5375)
# positive
# Sentiment(polarity=-0.19999999999999998, subjectivity=0.6666666666666666)
# negative
# Sentiment(polarity=-0.04000000000000001, subjectivity=0.22000000000000003)
# negative
# Sentiment(polarity=-0.07621527777777777, subjectivity=0.6333333333333333)
# negative
# Sentiment(polarity=-0.05, subjectivity=0.2)
# negative
# Sentiment(polarity=0.0675595238095238, subjectivity=0.6361111111111112)
# positive
# Sentiment(polarity=-0.09444444444444443, subjectivity=0.6916666666666665)
# negative
# Sentiment(polarity=0.1765151515151515, subjectivity=0.4128787878787879)
# positive
# Sentiment(polarity=0.030000000000000006, subjectivity=0.3)
# positive
# Sentiment(polarity=-0.11808191808191808, subjectivity=0.6470529470529471)
# negative
# Sentiment(polarity=0.1187037037037037, subjectivity=0.8025925925925926)
# positive
# Sentiment(polarity=-0.05208333333333333, subjectivity=0.5895833333333333)
# negative
# Sentiment(polarity=-0.3005952380952381, subjectivity=0.4746031746031745)
# negative
# Sentiment(polarity=0.10694444444444447, subjectivity=0.4592592592592592)
# positive
# Sentiment(polarity=0.0075000000000000015, subjectivity=0.44000000000000006)
# positive
# Sentiment(polarity=-0.2699999999999999, subjectivity=0.6033333333333333)
# negative
# Sentiment(polarity=0.275, subjectivity=0.5125)
# positive
# Sentiment(polarity=-0.001388888888888884, subjectivity=0.7888888888888889)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.24166666666666664, subjectivity=0.4287037037037037)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.06, subjectivity=0.5166666666666666)
# positive
# Sentiment(polarity=0.0642857142857143, subjectivity=0.3821428571428572)
# positive
# Sentiment(polarity=0.275, subjectivity=0.375)
# positive
# Sentiment(polarity=-0.14880952380952378, subjectivity=0.725)
# negative
# Sentiment(polarity=0.2791666666666667, subjectivity=0.42027777777777775)
# positive
# Sentiment(polarity=0.12499999999999999, subjectivity=0.5083333333333333)
# positive
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# Sentiment(polarity=0.7000000000000001, subjectivity=0.75)
# positive
# Sentiment(polarity=-0.03539682539682541, subjectivity=0.5486243386243386)
# negative
# Sentiment(polarity=0.09861111111111114, subjectivity=0.5555555555555556)
# positive
# Sentiment(polarity=0.22575757575757577, subjectivity=0.3612554112554113)
# positive
# Sentiment(polarity=0.10500000000000002, subjectivity=0.44666666666666666)
# positive
# Sentiment(polarity=0.12678571428571428, subjectivity=0.5922619047619048)
# positive
# Sentiment(polarity=0.3, subjectivity=0.30000000000000004)
# positive
# Sentiment(polarity=0.022023809523809525, subjectivity=0.5297619047619048)
# positive
# Sentiment(polarity=-0.104421768707483, subjectivity=0.5795918367346939)
# negative
# Sentiment(polarity=-0.14573863636363638, subjectivity=0.5375)
# negative
# Sentiment(polarity=0.07847222222222222, subjectivity=0.43888888888888894)
# positive
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# Sentiment(polarity=-0.029166666666666664, subjectivity=0.6356060606060606)
# negative
# Sentiment(polarity=0.2627083333333333, subjectivity=0.5508333333333333)
# positive
# Sentiment(polarity=0.30714285714285716, subjectivity=0.4642857142857143)
# positive
# Sentiment(polarity=0.09212962962962962, subjectivity=0.4300925925925925)
# positive
# Sentiment(polarity=-0.14956709956709957, subjectivity=0.5346320346320346)
# negative
# Sentiment(polarity=-0.020959595959595963, subjectivity=0.42297979797979796)
# negative
# Sentiment(polarity=0.175, subjectivity=0.3)
# positive
# Sentiment(polarity=0.45, subjectivity=0.6035714285714285)
# positive
# Sentiment(polarity=0.06999999999999999, subjectivity=0.62)
# positive
# Sentiment(polarity=0.24083333333333332, subjectivity=0.5258333333333333)
# positive
# Sentiment(polarity=-0.021666666666666667, subjectivity=0.32333333333333336)
# negative
# Sentiment(polarity=0.43333333333333335, subjectivity=0.26666666666666666)
# positive
# Sentiment(polarity=0.39999999999999997, subjectivity=0.6249999999999999)
# positive
# Sentiment(polarity=0.005468750000000001, subjectivity=0.246875)
# positive
# Sentiment(polarity=-1.0, subjectivity=1.0)
# negative
# Sentiment(polarity=0.16666666666666666, subjectivity=0.7)
# positive
# Sentiment(polarity=-0.0441358024691358, subjectivity=0.46141975308641975)
# negative
# Sentiment(polarity=0.08926767676767677, subjectivity=0.577020202020202)
# positive
# Sentiment(polarity=0.11749999999999998, subjectivity=0.5925)
# positive
# Sentiment(polarity=0.1625, subjectivity=0.625)
# positive
# Sentiment(polarity=-0.024305555555555542, subjectivity=0.4597222222222222)
# negative
# Sentiment(polarity=0.19, subjectivity=0.51)
# positive
# Sentiment(polarity=-0.09246031746031745, subjectivity=0.5329365079365079)
# negative
# Sentiment(polarity=-0.04528754578754579, subjectivity=0.5046373626373626)
# negative
# Sentiment(polarity=0.13333333333333333, subjectivity=0.3277777777777777)
# positive
# Sentiment(polarity=0.41, subjectivity=0.6166666666666666)
# positive
# Sentiment(polarity=0.25, subjectivity=0.4944444444444444)
# positive
# Sentiment(polarity=-0.2571428571428572, subjectivity=0.7178571428571429)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=-0.06420454545454544, subjectivity=0.6120265151515151)
# negative
# Sentiment(polarity=0.65, subjectivity=0.75)
# positive
# Sentiment(polarity=0.11458333333333334, subjectivity=0.5291666666666667)
# positive
# Sentiment(polarity=-0.012878787878787878, subjectivity=0.35530303030303034)
# negative
# Sentiment(polarity=0.26125000000000004, subjectivity=0.37357142857142855)
# positive
# Sentiment(polarity=0.24545454545454545, subjectivity=0.3090909090909091)
# positive
# Sentiment(polarity=-0.29404761904761906, subjectivity=0.6976190476190475)
# negative
# Sentiment(polarity=0.049206349206349205, subjectivity=0.5225970017636684)
# positive
# Sentiment(polarity=0.17833333333333332, subjectivity=0.3503846153846154)
# positive
# Sentiment(polarity=-0.07953296703296703, subjectivity=0.4184065934065935)
# negative
# Sentiment(polarity=-0.11458333333333331, subjectivity=0.49090909090909096)
# negative
# Sentiment(polarity=0.20260416666666667, subjectivity=0.45625)
# positive
# Sentiment(polarity=-0.05714285714285714, subjectivity=0.5547619047619048)
# negative
# Sentiment(polarity=0.032142857142857154, subjectivity=0.46309523809523817)
# positive
# Sentiment(polarity=-0.05055272108843538, subjectivity=0.30459183673469387)
# negative
# Sentiment(polarity=-0.06684601113172542, subjectivity=0.4645269016697588)
# negative
# Sentiment(polarity=-0.05083333333333331, subjectivity=0.7002777777777777)
# negative
# Sentiment(polarity=0.18333333333333335, subjectivity=0.19999999999999998)
# positive
# Sentiment(polarity=-0.11825396825396825, subjectivity=0.5337301587301587)
# negative
# Sentiment(polarity=-0.09642857142857143, subjectivity=0.30848214285714287)
# negative
# Sentiment(polarity=-0.05083333333333333, subjectivity=0.6491666666666667)
# negative
# Sentiment(polarity=0.034297052154195026, subjectivity=0.5907879818594104)
# positive
# Sentiment(polarity=-0.03461538461538462, subjectivity=0.38782051282051283)
# negative
# Sentiment(polarity=0.11666666666666667, subjectivity=0.4538461538461539)
# positive
# Sentiment(polarity=0.5208333333333333, subjectivity=0.5)
# positive
# Sentiment(polarity=0.16180555555555554, subjectivity=0.5055555555555555)
# positive
# Sentiment(polarity=0.08725000000000002, subjectivity=0.579)
# positive
# Sentiment(polarity=0.015909090909090904, subjectivity=0.32803030303030306)
# positive
# Sentiment(polarity=-0.045, subjectivity=0.45499999999999996)
# negative
# Sentiment(polarity=0.175, subjectivity=0.6533333333333333)
# positive
# Sentiment(polarity=0.2625, subjectivity=0.4666666666666666)
# positive
# Sentiment(polarity=0.06666666666666667, subjectivity=0.4069444444444444)
# positive
# Sentiment(polarity=0.144375, subjectivity=0.5164583333333334)
# positive
# Sentiment(polarity=0.11767676767676769, subjectivity=0.47020202020202023)
# positive
# Sentiment(polarity=0.2416666666666667, subjectivity=0.47916666666666663)
# positive
# Sentiment(polarity=0.2833333333333334, subjectivity=0.5794871794871795)
# positive
# Sentiment(polarity=0.2791666666666667, subjectivity=0.4)
# positive
# Sentiment(polarity=-0.5499999999999999, subjectivity=0.6333333333333333)
# negative
# Sentiment(polarity=0.05, subjectivity=1.0)
# positive
# Sentiment(polarity=-0.1636904761904762, subjectivity=0.41592261904761907)
# negative
# Sentiment(polarity=-0.09722222222222222, subjectivity=0.2638888888888889)
# negative
# Sentiment(polarity=0.55, subjectivity=0.25)
# positive
# Sentiment(polarity=0.1875, subjectivity=0.4444444444444444)
# positive
# Sentiment(polarity=0.01666666666666667, subjectivity=0.26666666666666666)
# positive
# Sentiment(polarity=0.14895833333333333, subjectivity=0.5857142857142856)
# positive
# Sentiment(polarity=0.3499999999999999, subjectivity=0.6666666666666666)
# positive
# Sentiment(polarity=0.012083333333333335, subjectivity=0.39000000000000007)
# positive
# Sentiment(polarity=-0.13194444444444445, subjectivity=0.46666666666666673)
# negative
# Sentiment(polarity=-0.037083333333333336, subjectivity=0.7012499999999999)
# negative
# Sentiment(polarity=0.8, subjectivity=0.75)
# positive
# Sentiment(polarity=0.007352941176470598, subjectivity=0.4142156862745097)
# positive
# Sentiment(polarity=0.011868686868686865, subjectivity=0.43474747474747477)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.22999999999999998, subjectivity=0.7666666666666667)
# positive
# Sentiment(polarity=0.23143939393939394, subjectivity=0.3501748251748251)
# positive
# Sentiment(polarity=0.2197619047619048, subjectivity=0.5570238095238096)
# positive
# Sentiment(polarity=-0.05416666666666666, subjectivity=0.5421428571428571)
# negative
# Sentiment(polarity=0.8, subjectivity=0.75)
# positive
# Sentiment(polarity=0.043333333333333335, subjectivity=0.6066666666666666)
# positive
# Sentiment(polarity=-0.17604166666666665, subjectivity=0.7520833333333333)
# negative
# Sentiment(polarity=1.0, subjectivity=0.75)
# positive
# Sentiment(polarity=0.033055555555555574, subjectivity=0.495)
# positive
# Sentiment(polarity=0.103125, subjectivity=0.425)
# positive
# Sentiment(polarity=-0.15576171875, subjectivity=0.5729166666666666)
# negative
# Sentiment(polarity=-0.05952380952380952, subjectivity=0.30476190476190473)
# negative
# Sentiment(polarity=0.22187500000000004, subjectivity=0.5125)
# positive
# Sentiment(polarity=0.06329365079365079, subjectivity=0.4920634920634921)
# positive
# Sentiment(polarity=-0.17373737373737372, subjectivity=0.6657407407407407)
# negative
# Sentiment(polarity=0.2666666666666666, subjectivity=0.7)
# positive
# Sentiment(polarity=-0.3, subjectivity=0.5)
# negative
# Sentiment(polarity=-0.11818181818181817, subjectivity=0.6151515151515152)
# negative
# Sentiment(polarity=0.00944444444444445, subjectivity=0.4372222222222222)
# positive
# Sentiment(polarity=0.06999999999999999, subjectivity=0.42666666666666664)
# positive
# Sentiment(polarity=-0.44999999999999996, subjectivity=0.7000000000000001)
# negative
# Sentiment(polarity=0.12727272727272726, subjectivity=0.5416666666666667)
# positive
# Sentiment(polarity=-0.034876543209876536, subjectivity=0.5453703703703705)
# negative
# Sentiment(polarity=0.17670454545454542, subjectivity=0.5335700757575758)
# positive
# Sentiment(polarity=0.16666666666666666, subjectivity=0.576388888888889)
# positive
# Sentiment(polarity=0.0756578947368421, subjectivity=0.6127192982456141)
# positive
# Sentiment(polarity=0.14071428571428574, subjectivity=0.5933333333333334)
# positive
# Sentiment(polarity=0.1079985119047619, subjectivity=0.35078983516483514)
# positive
# Sentiment(polarity=0.14166666666666666, subjectivity=0.6333333333333333)
# positive
# Sentiment(polarity=0.1872727272727272, subjectivity=0.6709090909090909)
# positive
# Sentiment(polarity=-0.05688775510204084, subjectivity=0.539795918367347)
# negative
# Sentiment(polarity=-0.17936507936507937, subjectivity=0.6373015873015873)
# negative
# Sentiment(polarity=0.11071428571428572, subjectivity=0.30773809523809526)
# positive
# Sentiment(polarity=0.15415151515151515, subjectivity=0.5003939393939394)
# positive
# Sentiment(polarity=0.11989583333333334, subjectivity=0.49272435897435907)
# positive
# Sentiment(polarity=0.08518518518518518, subjectivity=0.6092592592592593)
# positive
# Sentiment(polarity=0.15333333333333332, subjectivity=0.48)
# positive
# Sentiment(polarity=-0.19687500000000002, subjectivity=0.6781250000000001)
# negative
# Sentiment(polarity=-0.025773809523809515, subjectivity=0.42833333333333334)
# negative
# Sentiment(polarity=-0.10999999999999996, subjectivity=0.4076923076923077)
# negative
# Sentiment(polarity=0.2552777777777778, subjectivity=0.4105555555555555)
# positive
# Sentiment(polarity=-0.036250000000000004, subjectivity=0.5591666666666666)
# negative
# Sentiment(polarity=0.03928571428571427, subjectivity=0.6714285714285715)
# positive
# Sentiment(polarity=-0.11218750000000002, subjectivity=0.7075)
# negative
# Sentiment(polarity=-0.013541666666666664, subjectivity=0.33854166666666663)
# negative
# Sentiment(polarity=0.15000000000000005, subjectivity=0.85)
# positive
# Sentiment(polarity=0.04, subjectivity=0.3966666666666666)
# positive
# Sentiment(polarity=0.08, subjectivity=0.27999999999999997)
# positive
# Sentiment(polarity=-0.10000000000000002, subjectivity=0.75)
# negative
# Sentiment(polarity=-0.08682900432900434, subjectivity=0.5312770562770562)
# negative
# Sentiment(polarity=0.053571428571428575, subjectivity=0.47410714285714284)
# positive
# Sentiment(polarity=0.11650641025641024, subjectivity=0.3141025641025641)
# positive
# Sentiment(polarity=-0.10872727272727278, subjectivity=0.7909090909090909)
# negative
# Sentiment(polarity=0.015625, subjectivity=0.4502403846153846)
# positive
# Sentiment(polarity=-0.20988455988455984, subjectivity=0.3681096681096681)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=-0.2288095238095238, subjectivity=0.4484126984126983)
# negative
# Sentiment(polarity=-0.0978277674706246, subjectivity=0.44751855287569564)
# negative
# Sentiment(polarity=0.17, subjectivity=0.4916666666666667)
# positive
# Sentiment(polarity=0.18, subjectivity=0.33999999999999997)
# positive
# Sentiment(polarity=-0.10309523809523809, subjectivity=0.5498809523809525)
# negative
# Sentiment(polarity=0.29, subjectivity=0.38)
# positive
# Sentiment(polarity=0.017336309523809528, subjectivity=0.38973214285714286)
# positive
# Sentiment(polarity=0.07952380952380952, subjectivity=0.5485185185185185)
# positive
# Sentiment(polarity=0.2801027097902098, subjectivity=0.4073426573426574)
# positive
# Sentiment(polarity=-0.045, subjectivity=0.20166666666666666)
# negative
# Sentiment(polarity=0.1181818181818182, subjectivity=0.527922077922078)
# positive
# Sentiment(polarity=-0.08222222222222222, subjectivity=0.6161111111111112)
# negative
# Sentiment(polarity=0.23214285714285715, subjectivity=0.4869047619047619)
# positive
# Sentiment(polarity=-0.07896825396825395, subjectivity=0.45714285714285713)
# negative
# Sentiment(polarity=0.3669642857142857, subjectivity=0.37946428571428575)
# positive
# Sentiment(polarity=0.3302517361111111, subjectivity=0.45972222222222225)
# positive
# Sentiment(polarity=0.4, subjectivity=0.95)
# positive
# Sentiment(polarity=0.012272727272727274, subjectivity=0.38393939393939397)
# positive
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.5)
# negative
# Sentiment(polarity=0.05937500000000002, subjectivity=0.4427083333333333)
# positive
# Sentiment(polarity=0.15277777777777776, subjectivity=0.5138888888888888)
# positive
# Sentiment(polarity=0.15388888888888885, subjectivity=0.4872222222222223)
# positive
# Sentiment(polarity=0.4000000000000001, subjectivity=0.7666666666666666)
# positive
# Sentiment(polarity=-0.1337890625, subjectivity=0.753125)
# negative
# Sentiment(polarity=-0.05, subjectivity=0.425)
# negative
# Sentiment(polarity=0.08939393939393937, subjectivity=0.587878787878788)
# positive
# Sentiment(polarity=0.06538461538461537, subjectivity=0.4948717948717949)
# positive
# Sentiment(polarity=-0.05972222222222223, subjectivity=0.3955555555555556)
# negative
# Sentiment(polarity=-0.04895833333333333, subjectivity=0.4927083333333334)
# negative
# Sentiment(polarity=0.2748456790123457, subjectivity=0.3901234567901235)
# positive
# Sentiment(polarity=0.20779220779220778, subjectivity=0.46428571428571425)
# positive
# Sentiment(polarity=0.23125, subjectivity=0.38958333333333334)
# positive
# Sentiment(polarity=-0.055601851851851854, subjectivity=0.38907407407407407)
# negative
# Sentiment(polarity=0.2046875, subjectivity=0.45625000000000004)
# positive
# Sentiment(polarity=-0.018750000000000024, subjectivity=0.4645833333333334)
# negative
# Sentiment(polarity=0.017613636363636366, subjectivity=0.3909090909090909)
# positive
# Sentiment(polarity=0.018650793650793647, subjectivity=0.38412698412698415)
# positive
# Sentiment(polarity=-0.11666666666666665, subjectivity=0.6472222222222223)
# negative
# Sentiment(polarity=-0.15625, subjectivity=0.825)
# negative
# Sentiment(polarity=-0.13333333333333333, subjectivity=0.5481481481481482)
# negative
# Sentiment(polarity=0.1265151515151515, subjectivity=0.7333333333333333)
# positive
# Sentiment(polarity=0.0625, subjectivity=0.08333333333333333)
# positive
# Sentiment(polarity=0.05714285714285715, subjectivity=0.3285714285714286)
# positive
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# negative
# Sentiment(polarity=-0.012499999999999999, subjectivity=0.4527777777777778)
# negative
# Sentiment(polarity=0.08333333333333336, subjectivity=0.44375000000000003)
# positive
# Sentiment(polarity=-0.09375, subjectivity=0.5361111111111111)
# negative
# Sentiment(polarity=0.4068888888888889, subjectivity=0.7077777777777777)
# positive
# Sentiment(polarity=0.12222699652777777, subjectivity=0.5438888888888889)
# positive
# Sentiment(polarity=-0.3, subjectivity=0.6166666666666667)
# negative
# Sentiment(polarity=0.49416666666666664, subjectivity=0.7633333333333333)
# positive
# Sentiment(polarity=0.23611111111111108, subjectivity=0.2805555555555555)
# positive
# Sentiment(polarity=0.1409090909090909, subjectivity=0.4806818181818182)
# positive
# Sentiment(polarity=0.265625, subjectivity=0.6458333333333334)
# positive
# Sentiment(polarity=-0.2524553571428571, subjectivity=0.646825396825397)
# negative
# Sentiment(polarity=-0.059412202380952385, subjectivity=0.35409226190476195)
# negative
# Sentiment(polarity=0.255, subjectivity=0.505)
# positive
# Sentiment(polarity=0.07662337662337662, subjectivity=0.36493506493506495)
# positive
# Sentiment(polarity=0.012500000000000004, subjectivity=0.6375)
# positive
# Sentiment(polarity=0.165625, subjectivity=0.409375)
# positive
# Sentiment(polarity=-0.10555555555555557, subjectivity=0.6888888888888888)
# negative
# Sentiment(polarity=0.11875000000000001, subjectivity=0.3638888888888889)
# positive
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# negative
# Sentiment(polarity=0.04444444444444445, subjectivity=0.3888888888888889)
# positive
# Sentiment(polarity=0.16527777777777777, subjectivity=0.5388888888888889)
# positive
# Sentiment(polarity=0.1, subjectivity=0.3)
# positive
# Sentiment(polarity=-0.1625, subjectivity=0.2375)
# negative
# Sentiment(polarity=-0.30208333333333337, subjectivity=0.3958333333333333)
# negative
# Sentiment(polarity=0.575, subjectivity=0.925)
# positive
# Sentiment(polarity=-0.016626602564102564, subjectivity=0.5128205128205129)
# negative
# Sentiment(polarity=0.09912280701754388, subjectivity=0.5513157894736842)
# positive
# Sentiment(polarity=-0.08582451499118163, subjectivity=0.4930335097001764)
# negative
# Sentiment(polarity=0.10234788359788359, subjectivity=0.4391534391534392)
# positive
# Sentiment(polarity=0.10000000000000003, subjectivity=0.5180555555555555)
# positive
# Sentiment(polarity=-0.2, subjectivity=0.85)
# negative
# Sentiment(polarity=-0.046875, subjectivity=0.43333333333333335)
# negative
# Sentiment(polarity=-0.2773809523809524, subjectivity=0.5876190476190476)
# negative
# Sentiment(polarity=-0.11803030303030304, subjectivity=0.5021212121212122)
# negative
# Sentiment(polarity=0.45714285714285713, subjectivity=0.4871428571428572)
# positive
# Sentiment(polarity=-0.53, subjectivity=0.7866666666666666)
# negative
# Sentiment(polarity=0.044191919191919206, subjectivity=0.4305050505050506)
# positive
# Sentiment(polarity=0.41111111111111115, subjectivity=0.7000000000000001)
# positive
# Sentiment(polarity=0.5249999999999999, subjectivity=0.6333333333333333)
# positive
# Sentiment(polarity=-0.057291666666666664, subjectivity=0.3604166666666666)
# negative
# Sentiment(polarity=0.3, subjectivity=0.36111111111111116)
# positive
# Sentiment(polarity=0.009958791208791212, subjectivity=0.48031135531135527)
# positive
# Sentiment(polarity=0.05555555555555555, subjectivity=0.3259259259259259)
# positive
# Sentiment(polarity=0.14074074074074075, subjectivity=0.5166666666666667)
# positive
# Sentiment(polarity=0.1590909090909091, subjectivity=0.625)
# positive
# Sentiment(polarity=0.023260073260073257, subjectivity=0.497985347985348)
# positive
# Sentiment(polarity=-0.1239955357142857, subjectivity=0.48571428571428577)
# negative
# Sentiment(polarity=-0.06203703703703703, subjectivity=0.4887345679012346)
# negative
# Sentiment(polarity=0.15866316223459082, subjectivity=0.5332044939187796)
# positive
# Sentiment(polarity=0.15297619047619046, subjectivity=0.5380952380952382)
# positive
# Sentiment(polarity=0.11904761904761904, subjectivity=0.6476190476190476)
# positive
# Sentiment(polarity=0.09999999999999999, subjectivity=0.35833333333333334)
# positive
# Sentiment(polarity=-0.021825396825396814, subjectivity=0.48373015873015873)
# negative
# Sentiment(polarity=0.134, subjectivity=0.615)
# positive
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
# Sentiment(polarity=-0.14761904761904762, subjectivity=0.5303571428571429)
# negative
# Sentiment(polarity=-0.20833333333333334, subjectivity=0.625)
# negative
# Sentiment(polarity=0.24999999999999997, subjectivity=0.476388888888889)
# positive
# Sentiment(polarity=0.1339285714285714, subjectivity=0.575595238095238)
# positive
# Sentiment(polarity=0.03492063492063492, subjectivity=0.3531746031746032)
# positive
# Sentiment(polarity=0.13999999999999999, subjectivity=0.6)
# positive
# Sentiment(polarity=0.13762626262626265, subjectivity=0.31132478632478633)
# positive
# Sentiment(polarity=0.4583333333333333, subjectivity=0.5833333333333334)
# positive
# Sentiment(polarity=0.05000000000000001, subjectivity=0.6666666666666666)
# positive
# Sentiment(polarity=-0.23055555555555554, subjectivity=0.4472222222222222)
# negative
# Sentiment(polarity=0.23809523809523808, subjectivity=0.4956349206349207)
# positive
# Sentiment(polarity=-0.18416666666666665, subjectivity=0.6475)
# negative
# Sentiment(polarity=0.4708333333333334, subjectivity=0.7666666666666666)
# positive
# Sentiment(polarity=0.12458333333333334, subjectivity=0.6508333333333333)
# positive
# Sentiment(polarity=0.030769230769230778, subjectivity=0.4012820512820513)
# positive
# Sentiment(polarity=0.01666666666666667, subjectivity=0.27527472527472524)
# positive
# Sentiment(polarity=-0.4666666666666666, subjectivity=0.3333333333333333)
# negative
# Sentiment(polarity=-0.19523809523809524, subjectivity=0.45110544217687076)
# negative
# Sentiment(polarity=-0.13999999999999996, subjectivity=0.5333333333333333)
# negative
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
# positive
# Sentiment(polarity=0.058333333333333355, subjectivity=0.5416666666666667)
# positive
# Sentiment(polarity=0.12230489417989417, subjectivity=0.53260582010582)
# positive
# Sentiment(polarity=0.16614583333333333, subjectivity=0.6229166666666667)
# positive
# Sentiment(polarity=-0.33124999999999993, subjectivity=0.5791666666666666)
# negative
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# positive
# Sentiment(polarity=0.30250000000000005, subjectivity=0.4574999999999999)
# positive
# Sentiment(polarity=-0.19761904761904764, subjectivity=0.5812698412698413)
# negative
# Sentiment(polarity=-0.10000000000000002, subjectivity=0.3833333333333333)
# negative
# Sentiment(polarity=0.10023809523809522, subjectivity=0.5459523809523811)
# positive
# Sentiment(polarity=-0.16904761904761906, subjectivity=0.546978021978022)
# negative
# Sentiment(polarity=0.18495370370370368, subjectivity=0.5976851851851851)
# positive
# Sentiment(polarity=0.19902356902356902, subjectivity=0.4042087542087541)
# positive
# Sentiment(polarity=0.15478395061728398, subjectivity=0.4728395061728395)
# positive
# Sentiment(polarity=0.10000000000000002, subjectivity=0.3833333333333333)
# positive
# Sentiment(polarity=0.07142857142857142, subjectivity=0.5833333333333334)
# positive
# Sentiment(polarity=0.1729166666666667, subjectivity=0.6395833333333334)
# positive
# Sentiment(polarity=0.37291666666666673, subjectivity=0.5363636363636364)
# positive
# Sentiment(polarity=-0.14525, subjectivity=0.41602777777777783)
# negative
# Sentiment(polarity=0.34, subjectivity=0.71)
# positive
# Sentiment(polarity=0.06183712121212121, subjectivity=0.46723484848484853)
# positive
# Sentiment(polarity=0.032142857142857154, subjectivity=0.46309523809523817)
# positive
# Sentiment(polarity=-0.08833333333333335, subjectivity=0.6491666666666667)
# negative
# Sentiment(polarity=-0.8499999999999999, subjectivity=0.8333333333333333)
# negative
# Sentiment(polarity=0.23296296296296296, subjectivity=0.36703703703703705)
# positive
# Sentiment(polarity=-0.006342592592592554, subjectivity=0.5837962962962961)
# negative
# Sentiment(polarity=0.25, subjectivity=0.2833333333333333)
# positive
# Sentiment(polarity=0.05081168831168831, subjectivity=0.46520562770562773)
# positive
# Sentiment(polarity=-0.12166666666666667, subjectivity=0.41833333333333345)
# negative
# Sentiment(polarity=-0.034285714285714274, subjectivity=0.5471428571428572)
# negative
# Sentiment(polarity=0.18958333333333333, subjectivity=0.2888888888888889)
# positive
# Sentiment(polarity=0.07556818181818183, subjectivity=0.45511363636363633)
# positive
# Sentiment(polarity=0.06605113636363637, subjectivity=0.5247474747474747)
# positive
# Sentiment(polarity=0.052222222222222205, subjectivity=0.4437037037037037)
# positive
# Sentiment(polarity=0.04027777777777777, subjectivity=0.47500000000000003)
# positive
# Sentiment(polarity=-0.035714285714285705, subjectivity=0.41428571428571426)
# negative
# Sentiment(polarity=0.3425, subjectivity=0.71875)
# positive
# Sentiment(polarity=0.19333333333333333, subjectivity=0.4916666666666667)
# positive
# Sentiment(polarity=0.19375, subjectivity=0.528125)
# positive
# Sentiment(polarity=-0.1277777777777778, subjectivity=0.4444444444444444)
# negative
# Sentiment(polarity=0.42500000000000004, subjectivity=0.9)
# positive
# Sentiment(polarity=-0.1561111111111111, subjectivity=0.475)
# negative
# Sentiment(polarity=0.04057422969187674, subjectivity=0.5132539682539683)
# positive
# Sentiment(polarity=0.009523809523809521, subjectivity=0.45476190476190476)
# positive
# Sentiment(polarity=0.08518518518518518, subjectivity=0.49259259259259264)
# positive
# Sentiment(polarity=-0.029166666666666646, subjectivity=0.375)
# negative
# Sentiment(polarity=-0.36, subjectivity=0.56)
# negative
# Sentiment(polarity=0.0892857142857143, subjectivity=0.7154761904761904)
# positive
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# Sentiment(polarity=-0.075, subjectivity=0.625)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.09679487179487181, subjectivity=0.5134615384615385)
# positive
# Sentiment(polarity=0.071, subjectivity=0.675)
# positive
# Sentiment(polarity=-0.19322916666666665, subjectivity=0.5980952380952381)
# negative
# Sentiment(polarity=-0.21250000000000002, subjectivity=0.8034722222222221)
# negative
# Sentiment(polarity=-0.18499999999999997, subjectivity=0.7166666666666667)
# negative
# Sentiment(polarity=0.1, subjectivity=0.40166666666666667)
# positive
# Sentiment(polarity=-0.08103864734299517, subjectivity=0.482487922705314)
# negative
# Sentiment(polarity=-0.12499999999999999, subjectivity=0.5208333333333333)
# negative
# Sentiment(polarity=0.10833333333333332, subjectivity=0.6333333333333333)
# positive
# Sentiment(polarity=0.3333333333333333, subjectivity=0.3666666666666667)
# positive
# Sentiment(polarity=0.03106060606060607, subjectivity=0.4856060606060606)
# positive
# Sentiment(polarity=0.08411172161172162, subjectivity=0.4844845630559917)
# positive
# Sentiment(polarity=0.16718750000000004, subjectivity=0.6333333333333333)
# positive
# Sentiment(polarity=0.4, subjectivity=0.9)
# positive
# Sentiment(polarity=-0.2857142857142857, subjectivity=0.6976190476190476)
# negative
# Sentiment(polarity=0.3666666666666667, subjectivity=0.7999999999999999)
# positive
# Sentiment(polarity=0.3666666666666667, subjectivity=0.5166666666666667)
# positive
# Sentiment(polarity=-0.021666666666666667, subjectivity=0.64)
# negative
# Sentiment(polarity=-0.14583333333333334, subjectivity=0.25)
# negative
# Sentiment(polarity=0.10810185185185185, subjectivity=0.5833333333333334)
# positive
# Sentiment(polarity=0.06944444444444443, subjectivity=0.4361111111111111)
# positive
# Sentiment(polarity=0.12500000000000003, subjectivity=0.5145833333333333)
# positive
# Sentiment(polarity=0.16, subjectivity=0.5055555555555554)
# positive
# Sentiment(polarity=0.38333333333333336, subjectivity=0.5289173789173789)
# positive
# Sentiment(polarity=0.030194805194805194, subjectivity=0.5435064935064935)
# positive
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# positive
# Sentiment(polarity=-0.0630952380952381, subjectivity=0.425)
# negative
# Sentiment(polarity=-0.05353535353535357, subjectivity=0.427020202020202)
# negative
# Sentiment(polarity=0.23666666666666666, subjectivity=0.41833333333333333)
# positive
# Sentiment(polarity=-0.2857142857142857, subjectivity=0.6678571428571429)
# negative
# Sentiment(polarity=0.30000000000000004, subjectivity=0.54375)
# positive
# Sentiment(polarity=0.39999999999999997, subjectivity=0.8)
# positive
# Sentiment(polarity=0.0170138888888889, subjectivity=0.48125)
# positive
# Sentiment(polarity=-0.16302083333333334, subjectivity=0.5729166666666666)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=7.93016446160826e-18, subjectivity=0.3892857142857143)
# positive
# Sentiment(polarity=0.27935606060606055, subjectivity=0.7196969696969697)
# positive
# Sentiment(polarity=0.3625, subjectivity=0.525)
# positive
# Sentiment(polarity=0.04583333333333335, subjectivity=0.5458333333333333)
# positive
# Sentiment(polarity=0.07722222222222218, subjectivity=0.601111111111111)
# positive
# Sentiment(polarity=-0.023529411764705868, subjectivity=0.472549019607843)
# negative
# Sentiment(polarity=0.14200216450216452, subjectivity=0.5702453102453102)
# positive
# Sentiment(polarity=-0.1020833333333333, subjectivity=0.49774305555555565)
# negative
# Sentiment(polarity=-0.2, subjectivity=0.2)
# negative
# Sentiment(polarity=-0.0031250000000000167, subjectivity=0.5322916666666666)
# negative
# Sentiment(polarity=0.18333333333333332, subjectivity=0.38333333333333336)
# positive
# Sentiment(polarity=0.475, subjectivity=0.8)
# positive
# Sentiment(polarity=0.3385416666666667, subjectivity=0.4930555555555555)
# positive
# Sentiment(polarity=0.10267857142857142, subjectivity=0.5628571428571428)
# positive
# Sentiment(polarity=0.11500000000000002, subjectivity=0.5725)
# positive
# Sentiment(polarity=0.2148148148148148, subjectivity=0.4962962962962963)
# positive
# Sentiment(polarity=-0.12035714285714283, subjectivity=0.40476190476190477)
# negative
# Sentiment(polarity=-0.085, subjectivity=0.43499999999999994)
# negative
# Sentiment(polarity=-0.032708333333333325, subjectivity=0.4691666666666666)
# negative
# Sentiment(polarity=0.17333333333333334, subjectivity=0.42333333333333334)
# positive
# Sentiment(polarity=0.09000000000000002, subjectivity=0.5083333333333334)
# positive
# Sentiment(polarity=-0.16999999999999998, subjectivity=0.5766666666666667)
# negative
# Sentiment(polarity=0.19554122574955907, subjectivity=0.4645612874779541)
# positive
# Sentiment(polarity=-0.175, subjectivity=0.37812500000000004)
# negative
# Sentiment(polarity=0.0738095238095238, subjectivity=0.2845238095238095)
# positive
# Sentiment(polarity=0.013888888888888888, subjectivity=0.550925925925926)
# positive
# Sentiment(polarity=0.10499999999999998, subjectivity=0.545)
# positive
# Sentiment(polarity=0.55, subjectivity=0.65)
# positive
# Sentiment(polarity=-0.011111111111111096, subjectivity=0.3535185185185185)
# negative
# Sentiment(polarity=-0.022222222222222216, subjectivity=0.2333333333333333)
# negative
# Sentiment(polarity=-0.15, subjectivity=0.5499999999999999)
# negative
# Sentiment(polarity=-0.022321428571428572, subjectivity=0.40833333333333327)
# negative
# Sentiment(polarity=0.1722537878787879, subjectivity=0.39431818181818185)
# positive
# Sentiment(polarity=0.05333333333333333, subjectivity=0.4138095238095238)
# positive
# Sentiment(polarity=0.04738888888888891, subjectivity=0.551)
# positive
# Sentiment(polarity=0.04545454545454545, subjectivity=0.38484848484848483)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.0, subjectivity=0.4666666666666666)
# neutral
# Sentiment(polarity=0.55, subjectivity=0.375)
# positive
# Sentiment(polarity=-0.036111111111111115, subjectivity=0.425)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.04341269841269843, subjectivity=0.6181746031746032)
# positive
# Sentiment(polarity=0.15564814814814815, subjectivity=0.4138888888888889)
# positive
# Sentiment(polarity=-0.021666666666666664, subjectivity=0.24666666666666667)
# negative
# Sentiment(polarity=0.021818181818181827, subjectivity=0.5352525252525253)
# positive
# Sentiment(polarity=0.1530753968253968, subjectivity=0.6106150793650794)
# positive
# Sentiment(polarity=-0.13263888888888886, subjectivity=0.5493055555555555)
# negative
# Sentiment(polarity=0.08611111111111108, subjectivity=0.45)
# positive
# Sentiment(polarity=0.08703703703703704, subjectivity=0.341358024691358)
# positive
# Sentiment(polarity=0.19942762586805557, subjectivity=0.5265277777777778)
# positive
# Sentiment(polarity=0.25, subjectivity=0.3125)
# positive
# Sentiment(polarity=-0.14375, subjectivity=0.45)
# negative
# Sentiment(polarity=0.015787981859410435, subjectivity=0.5582766439909297)
# positive
# Sentiment(polarity=0.014903846153846153, subjectivity=0.5153846153846154)
# positive
# Sentiment(polarity=0.0825, subjectivity=0.22749999999999998)
# positive
# Sentiment(polarity=0.1483333333333333, subjectivity=0.635)
# positive
# Sentiment(polarity=0.30166666666666664, subjectivity=0.5183333333333333)
# positive
# Sentiment(polarity=0.19678571428571429, subjectivity=0.6264285714285713)
# positive
# Sentiment(polarity=0.19354166666666667, subjectivity=0.5799999999999998)
# positive
# Sentiment(polarity=0.16428571428571428, subjectivity=0.5428571428571428)
# positive
# Sentiment(polarity=0.22499999999999995, subjectivity=0.4839285714285715)
# positive
# Sentiment(polarity=0.23714285714285716, subjectivity=0.4871428571428572)
# positive
# Sentiment(polarity=0.23712121212121212, subjectivity=0.425)
# positive
# Sentiment(polarity=0.1101851851851852, subjectivity=0.41018518518518515)
# positive
# Sentiment(polarity=0.3181818181818182, subjectivity=0.4772727272727273)
# positive
# Sentiment(polarity=0.013461538461538443, subjectivity=0.4596153846153846)
# positive
# Sentiment(polarity=0.029880952380952383, subjectivity=0.5334920634920635)
# positive
# Sentiment(polarity=0.3499999999999999, subjectivity=0.6666666666666666)
# positive
# Sentiment(polarity=0.29545454545454547, subjectivity=0.5931818181818183)
# positive
# Sentiment(polarity=-0.05813492063492063, subjectivity=0.6742063492063491)
# negative
# Sentiment(polarity=-0.039999999999999994, subjectivity=0.7133333333333333)
# negative
# Sentiment(polarity=-0.22291666666666665, subjectivity=0.45208333333333334)
# negative
# Sentiment(polarity=0.1875, subjectivity=0.20833333333333331)
# positive
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.48095238095238096)
# negative
# Sentiment(polarity=0.13148148148148148, subjectivity=0.3720899470899471)
# positive
# Sentiment(polarity=0.07708333333333334, subjectivity=0.41875)
# positive
# Sentiment(polarity=0.1875, subjectivity=0.7)
# positive
# Sentiment(polarity=-0.09999999999999999, subjectivity=0.5)
# negative
# Sentiment(polarity=0.050595238095238096, subjectivity=0.6464285714285714)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.028902116402116422, subjectivity=0.455026455026455)
# positive
# Sentiment(polarity=-0.14242424242424243, subjectivity=0.5777777777777778)
# negative
# Sentiment(polarity=0.09427083333333333, subjectivity=0.5088541666666666)
# positive
# Sentiment(polarity=0.0725, subjectivity=0.4466666666666666)
# positive
# Sentiment(polarity=0.13541666666666666, subjectivity=0.5083333333333334)
# positive
# Sentiment(polarity=-0.24166666666666667, subjectivity=0.40972222222222227)
# negative
# Sentiment(polarity=0.11666666666666665, subjectivity=0.45)
# positive
# Sentiment(polarity=0.20000000000000007, subjectivity=0.6541666666666667)
# positive
# Sentiment(polarity=0.10863095238095238, subjectivity=0.5071428571428571)
# positive
# Sentiment(polarity=0.04105902777777778, subjectivity=0.6024305555555556)
# positive
# Sentiment(polarity=-0.13333333333333333, subjectivity=0.4166666666666667)
# negative
# Sentiment(polarity=0.005000000000000049, subjectivity=0.4733333333333333)
# positive
# Sentiment(polarity=0.08055555555555555, subjectivity=0.30833333333333335)
# positive
# Sentiment(polarity=-0.065625, subjectivity=0.5979166666666665)
# negative
# Sentiment(polarity=-0.25, subjectivity=0.45)
# negative
# Sentiment(polarity=0.3599537037037037, subjectivity=0.5268518518518518)
# positive
# Sentiment(polarity=0.16522108843537417, subjectivity=0.5843537414965987)
# positive
# Sentiment(polarity=-0.44166666666666665, subjectivity=0.7666666666666666)
# negative
# Sentiment(polarity=0.27142857142857146, subjectivity=0.6922619047619047)
# positive
# Sentiment(polarity=0.33076923076923076, subjectivity=0.6192307692307693)
# positive
# Sentiment(polarity=0.0, subjectivity=0.5333333333333333)
# neutral
# Sentiment(polarity=-0.003703703703703715, subjectivity=0.4196581196581197)
# negative
# Sentiment(polarity=-0.2146666666666667, subjectivity=0.631)
# negative
# Sentiment(polarity=0.10555555555555556, subjectivity=0.29444444444444445)
# positive
# Sentiment(polarity=0.06408730158730158, subjectivity=0.3765873015873016)
# positive
# Sentiment(polarity=0.2041666666666667, subjectivity=0.3666666666666667)
# positive
# Sentiment(polarity=0.10769230769230773, subjectivity=0.5217948717948718)
# positive
# Sentiment(polarity=0.14114583333333333, subjectivity=0.4494791666666666)
# positive
# Sentiment(polarity=-0.022916666666666658, subjectivity=0.5805555555555555)
# negative
# Sentiment(polarity=0.3536630036630037, subjectivity=0.4931013431013431)
# positive
# Sentiment(polarity=0.15928571428571425, subjectivity=0.5420535714285715)
# positive
# Sentiment(polarity=0.15243055555555554, subjectivity=0.4583333333333333)
# positive
# Sentiment(polarity=0.15183333333333335, subjectivity=0.4573333333333334)
# positive
# Sentiment(polarity=0.015151515151515154, subjectivity=0.4997474747474747)
# positive
# Sentiment(polarity=0.06764705882352941, subjectivity=0.3931372549019607)
# positive
# Sentiment(polarity=-0.05937500000000001, subjectivity=0.24999999999999997)
# negative
# Sentiment(polarity=-0.13333333333333333, subjectivity=0.6)
# negative
# Sentiment(polarity=0.009999999999999998, subjectivity=0.6183333333333334)
# positive
# Sentiment(polarity=-0.04166666666666666, subjectivity=0.3416666666666667)
# negative
# Sentiment(polarity=-0.17414529914529914, subjectivity=0.716025641025641)
# negative
# Sentiment(polarity=0.11874999999999998, subjectivity=0.4979166666666666)
# positive
# Sentiment(polarity=0.06999999999999999, subjectivity=0.42666666666666664)
# positive
# Sentiment(polarity=-0.183598976780795, subjectivity=0.44575954348681623)
# negative
# ...
# positive
# Sentiment(polarity=0.2498511904761905, subjectivity=0.5849702380952381)
# positive
# Sentiment(polarity=-0.10916666666666666, subjectivity=0.5750000000000001)
# negative
# Sentiment(polarity=0.14583333333333334, subjectivity=0.5958333333333333)
# positive
# Sentiment(polarity=-0.34500000000000003, subjectivity=0.775)
# negative
# Sentiment(polarity=0.012828282828282843, subjectivity=0.6043434343434343)
# positive
# Sentiment(polarity=-0.1227272727272727, subjectivity=0.5696969696969696)
# negative
# Sentiment(polarity=0.06289062499999998, subjectivity=0.4354166666666667)
# positive
# Sentiment(polarity=-0.014069264069264068, subjectivity=0.45032467532467535)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=-0.01292735042735043, subjectivity=0.29090354090354087)
# negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.1621212121212121, subjectivity=0.3348484848484849)
# positive
# Sentiment(polarity=-0.215, subjectivity=0.9199999999999999)
# negative
# Sentiment(polarity=0.028571428571428564, subjectivity=0.41250000000000003)
# positive
# Sentiment(polarity=0.07973137973137973, subjectivity=0.42963980463980467)
# positive
# Sentiment(polarity=0.16964285714285715, subjectivity=0.3392857142857143)
# positive
# Sentiment(polarity=0.175, subjectivity=0.3666666666666667)
# positive
# Sentiment(polarity=-0.8255208333333333, subjectivity=0.8333333333333333)
# negative
# Sentiment(polarity=0.21214517625231913, subjectivity=0.47430426716141)
# positive
# Sentiment(polarity=0.10452441077441074, subjectivity=0.4580808080808081)
# positive
# Sentiment(polarity=-0.022222222222222227, subjectivity=0.3743055555555556)
# negative
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.8)
# negative
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
# Sentiment(polarity=0.02108585858585858, subjectivity=0.6273989898989899)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.2916666666666667, subjectivity=0.5750000000000001)
# positive
# Sentiment(polarity=0.03974358974358974, subjectivity=0.43205128205128207)
# positive
# Sentiment(polarity=0.1775, subjectivity=0.58)
# positive
# Sentiment(polarity=0.39250000000000007, subjectivity=0.8541666666666666)
# positive
# Sentiment(polarity=0.09074074074074072, subjectivity=0.2759259259259259)
# positive
# Sentiment(polarity=-0.13920454545454544, subjectivity=0.5626262626262627)
# negative
# Sentiment(polarity=-0.06547619047619048, subjectivity=0.3380952380952381)
# negative
# Sentiment(polarity=-0.19777777777777766, subjectivity=0.51)
# negative
# Sentiment(polarity=0.08027777777777778, subjectivity=0.5377777777777778)
# positive
# Sentiment(polarity=0.2535, subjectivity=0.534)
# positive
# Sentiment(polarity=0.15000000000000002, subjectivity=0.43333333333333335)
# positive
# Sentiment(polarity=-0.13333333333333333, subjectivity=0.6)
# negative
# Sentiment(polarity=-0.1, subjectivity=0.705)
# negative
# Sentiment(polarity=0.12777777777777774, subjectivity=0.5401709401709401)
# positive
# Sentiment(polarity=0.3, subjectivity=0.4571428571428572)
# positive
# Sentiment(polarity=0.06943132624950804, subjectivity=0.5438114915387642)
# positive
# Sentiment(polarity=-0.018703703703703705, subjectivity=0.43240740740740746)
# negative
# Sentiment(polarity=0.15555555555555556, subjectivity=0.47777777777777775)
# positive
# Sentiment(polarity=0.0, subjectivity=0.2222222222222222)
# neutral
# Sentiment(polarity=0.1537037037037037, subjectivity=0.4032407407407408)
# positive
# Sentiment(polarity=0.2827380952380953, subjectivity=0.47380952380952385)
# positive
# Sentiment(polarity=0.07666666666666666, subjectivity=0.6233333333333333)
# positive
# Sentiment(polarity=0.125, subjectivity=0.6625)
# positive
# Sentiment(polarity=0.09880952380952386, subjectivity=0.5785714285714285)
# positive
# Sentiment(polarity=0.37, subjectivity=0.6066666666666667)
# positive
# Sentiment(polarity=0.07179487179487183, subjectivity=0.47884615384615387)
# positive
# Sentiment(polarity=0.06813725490196078, subjectivity=0.3931372549019608)
# positive
# Sentiment(polarity=-0.14166666666666666, subjectivity=0.625)
# negative
# Sentiment(polarity=-0.062015993265993274, subjectivity=0.31264730639730637)
# negative
# Sentiment(polarity=0.3, subjectivity=0.7666666666666666)
# positive
# Sentiment(polarity=0.024999999999999994, subjectivity=0.3729166666666667)
# positive
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
# Sentiment(polarity=-0.16484374999999998, subjectivity=0.5781249999999999)
# negative
# Sentiment(polarity=0.1371527777777778, subjectivity=0.5444444444444444)
# positive
# Sentiment(polarity=0.35534188034188036, subjectivity=0.586965811965812)
# positive
# Sentiment(polarity=0.06608796296296297, subjectivity=0.30810185185185185)
# positive
# Sentiment(polarity=0.07467948717948716, subjectivity=0.3903846153846154)
# positive
# Sentiment(polarity=0.08, subjectivity=0.5127777777777778)
# positive
# Sentiment(polarity=0.25, subjectivity=0.4)
# positive
# Sentiment(polarity=-0.125, subjectivity=0.5833333333333333)
# negative
# Sentiment(polarity=0.11070105820105823, subjectivity=0.3508916700583367)
# positive
# Sentiment(polarity=0.16071428571428573, subjectivity=0.2678571428571429)
# positive
# Sentiment(polarity=0.025378787878787872, subjectivity=0.3909090909090909)
# positive
# Sentiment(polarity=-0.06664141414141414, subjectivity=0.4022474747474748)
# negative
# Sentiment(polarity=0.03208333333333333, subjectivity=0.3375)
# positive
# Sentiment(polarity=-0.013749999999999991, subjectivity=0.33749999999999997)
# negative
# Sentiment(polarity=0.09619047619047619, subjectivity=0.6338095238095238)
# positive
# Sentiment(polarity=-0.02380952380952382, subjectivity=0.4738095238095238)
# negative
# Sentiment(polarity=-0.04107142857142858, subjectivity=0.34226190476190477)
# negative
# Sentiment(polarity=0.0, subjectivity=0.6666666666666666)
# neutral
# Sentiment(polarity=-0.21319444444444446, subjectivity=0.517361111111111)
# negative
# Sentiment(polarity=0.12, subjectivity=0.3797222222222222)
# positive
# Sentiment(polarity=-0.018055555555555537, subjectivity=0.4791666666666667)
# negative
# Sentiment(polarity=0.10486111111111111, subjectivity=0.46782407407407406)
# positive
# Sentiment(polarity=0.08, subjectivity=0.6300000000000001)
# positive
# Sentiment(polarity=0.08525641025641027, subjectivity=0.5570512820512821)
# positive
# Sentiment(polarity=0.12083333333333333, subjectivity=0.6333333333333333)
# positive
# Sentiment(polarity=0.05, subjectivity=0.65)
# positive
# Sentiment(polarity=-0.11516666666666663, subjectivity=0.6325999999999999)
# negative
# Sentiment(polarity=0.14500000000000002, subjectivity=0.4925)
# positive
# Sentiment(polarity=0.03, subjectivity=0.4775)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.19, subjectivity=0.6016666666666668)
# positive
# Sentiment(polarity=0.375, subjectivity=0.875)
# positive
# Sentiment(polarity=0.11904761904761904, subjectivity=0.3904761904761905)
# positive
# Sentiment(polarity=-0.1725, subjectivity=0.5179166666666666)
# negative
# Sentiment(polarity=0.1361111111111111, subjectivity=0.5699074074074074)
# positive
# Sentiment(polarity=0.0413510101010101, subjectivity=0.4533459595959596)
# positive
# Sentiment(polarity=0.2054292929292929, subjectivity=0.5017676767676768)
# positive
# Sentiment(polarity=0.07414965986394559, subjectivity=0.5336734693877551)
# positive
# Sentiment(polarity=0.34375, subjectivity=0.75625)
# positive
# Sentiment(polarity=0.19145833333333337, subjectivity=0.5375)
# positive
# Sentiment(polarity=0.03541666666666666, subjectivity=0.6307291666666667)
# positive
# Sentiment(polarity=-0.12777777777777777, subjectivity=0.7999999999999999)
# negative
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# Sentiment(polarity=-0.10357142857142858, subjectivity=0.3392857142857143)
# negative
# Sentiment(polarity=-0.09768686868686866, subjectivity=0.486969696969697)
# negative
# Sentiment(polarity=0.3163690476190476, subjectivity=0.5059523809523809)
# positive
# Sentiment(polarity=0.08507154882154881, subjectivity=0.4877777777777777)
# positive
# Sentiment(polarity=0.1416666666666667, subjectivity=0.5666666666666667)
# positive
# Sentiment(polarity=0.14541666666666667, subjectivity=0.606388888888889)
# positive
# Sentiment(polarity=0.03928571428571429, subjectivity=0.569047619047619)
# positive
# Sentiment(polarity=0.29374999999999996, subjectivity=0.5187499999999999)
# positive
# Sentiment(polarity=0.22083333333333333, subjectivity=0.6236111111111111)
# positive
# Sentiment(polarity=0.24482142857142858, subjectivity=0.606904761904762)
# positive
# Sentiment(polarity=0.12250000000000001, subjectivity=0.5366666666666667)
# positive
# Sentiment(polarity=-0.05000000000000001, subjectivity=0.575)
# negative
# Sentiment(polarity=0.31666666666666665, subjectivity=0.6222222222222222)
# positive
# Sentiment(polarity=0.17407407407407405, subjectivity=0.46898148148148144)
# positive
# Sentiment(polarity=0.15763888888888888, subjectivity=0.26481481481481484)
# positive
# Sentiment(polarity=0.18418560606060605, subjectivity=0.652020202020202)
# positive
# Sentiment(polarity=0.24545454545454548, subjectivity=0.5916666666666666)
# positive
# Sentiment(polarity=0.08075396825396826, subjectivity=0.5200396825396826)
# positive
# Sentiment(polarity=-0.06999999999999999, subjectivity=0.63)
# negative
# Sentiment(polarity=0.15606060606060604, subjectivity=0.5318181818181817)
# positive
# Sentiment(polarity=0.020833333333333332, subjectivity=0.5513888888888889)
# positive
# Sentiment(polarity=0.26666666666666666, subjectivity=0.49047619047619045)
# positive
# Sentiment(polarity=0.1803030303030303, subjectivity=0.5612878787878788)
# positive
# Sentiment(polarity=0.30625, subjectivity=0.625)
# positive
# Sentiment(polarity=-0.28055555555555556, subjectivity=0.6685185185185185)
# negative
# Sentiment(polarity=0.030909090909090907, subjectivity=0.3381818181818182)
# positive
# Sentiment(polarity=0.10058333333333333, subjectivity=0.3998333333333333)
# positive
# Sentiment(polarity=0.5850000000000001, subjectivity=0.688888888888889)
# positive
# Sentiment(polarity=-0.05963203463203464, subjectivity=0.31536796536796535)
# negative
# Sentiment(polarity=0.1, subjectivity=0.18125000000000002)
# positive
# Sentiment(polarity=0.16, subjectivity=0.37777777777777777)
# positive
# Sentiment(polarity=0.25, subjectivity=0.3)
# positive
# Sentiment(polarity=0.12375992063492063, subjectivity=0.4475198412698413)
# positive
# Sentiment(polarity=-0.03165266106442576, subjectivity=0.5670168067226892)
# negative
# Sentiment(polarity=0.4388888888888889, subjectivity=0.701388888888889)
# positive
# Sentiment(polarity=0.11666666666666665, subjectivity=0.6166666666666667)
# positive
# Sentiment(polarity=0.76, subjectivity=0.65)
# positive
# Sentiment(polarity=0.1267156862745098, subjectivity=0.44885620915032676)
# positive
# Sentiment(polarity=-0.45, subjectivity=0.6)
# negative
# Sentiment(polarity=0.06666666666666664, subjectivity=0.546875)
# positive
# Sentiment(polarity=-0.14464285714285713, subjectivity=0.4279761904761905)
# negative
# Sentiment(polarity=0.8, subjectivity=1.0)
# positive
# Sentiment(polarity=-0.023173076923076925, subjectivity=0.3533333333333334)
# negative
# Sentiment(polarity=-0.1, subjectivity=0.6871428571428572)
# negative
# Sentiment(polarity=-0.24583333333333326, subjectivity=0.8222222222222223)
# negative
# Sentiment(polarity=-0.05799999999999998, subjectivity=0.488)
# negative
# Sentiment(polarity=0.08199826489300173, subjectivity=0.5459514170040487)
# positive
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3444444444444445)
# positive
# Sentiment(polarity=0.08333333333333333, subjectivity=0.2981481481481481)
# positive
# Sentiment(polarity=0.07435897435897439, subjectivity=0.6230769230769231)
# positive
# Sentiment(polarity=0.1125, subjectivity=0.21666666666666667)
# positive
# Sentiment(polarity=-0.05925925925925927, subjectivity=0.48518518518518516)
# negative
# Sentiment(polarity=0.2604166666666667, subjectivity=0.5388888888888889)
# positive
# Sentiment(polarity=-0.43285714285714294, subjectivity=0.6264285714285714)
# negative
# Sentiment(polarity=0.2333333333333333, subjectivity=0.5)
# positive
# Sentiment(polarity=0.14727272727272728, subjectivity=0.53)
# positive
# Sentiment(polarity=0.11093750000000001, subjectivity=0.35677083333333337)
# positive
# Sentiment(polarity=-0.03750000000000001, subjectivity=0.5888888888888888)
# negative
# Sentiment(polarity=0.06666666666666667, subjectivity=0.5393939393939393)
# positive
# Sentiment(polarity=-0.08777777777777777, subjectivity=0.3544444444444445)
# negative
# Sentiment(polarity=0.10729166666666667, subjectivity=0.3541666666666667)
# positive
# Sentiment(polarity=0.04375, subjectivity=0.425)
# positive
# Sentiment(polarity=0.08571428571428573, subjectivity=0.3964285714285714)
# positive
# Sentiment(polarity=-0.20833333333333331, subjectivity=0.5892857142857143)
# negative
# Sentiment(polarity=0.17656249999999998, subjectivity=0.575)
# positive
# Sentiment(polarity=0.018452380952380967, subjectivity=0.39908424908424905)
# positive
# Sentiment(polarity=0.325, subjectivity=0.41923076923076924)
# positive
# Sentiment(polarity=0.05416666666666667, subjectivity=0.3652777777777778)
# positive
# Sentiment(polarity=-0.03660714285714285, subjectivity=0.23273809523809522)
# negative
# Sentiment(polarity=-0.025, subjectivity=0.3625)
# negative
# Sentiment(polarity=-0.055555555555555546, subjectivity=0.4937500000000001)
# negative
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.8166666666666668)
# negative
# Sentiment(polarity=0.17962962962962964, subjectivity=0.4166666666666667)
# positive
# Sentiment(polarity=0.09583333333333335, subjectivity=0.24999999999999997)
# positive
# Sentiment(polarity=0.103125, subjectivity=0.425)
# positive
# Sentiment(polarity=0.1, subjectivity=0.2)
# positive
# Sentiment(polarity=-0.019886363636363646, subjectivity=0.6761363636363636)
# negative
# Sentiment(polarity=-0.06309523809523811, subjectivity=0.4166666666666667)
# negative
# Sentiment(polarity=0.10022222222222223, subjectivity=0.45200000000000007)
# positive
# Sentiment(polarity=0.3023809523809523, subjectivity=0.5476190476190477)
# positive
# Sentiment(polarity=0.08611111111111111, subjectivity=0.4305555555555556)
# positive
# Sentiment(polarity=0.05555555555555555, subjectivity=0.6253086419753087)
# positive
# Sentiment(polarity=-0.12916666666666668, subjectivity=0.5333333333333333)
# negative
# Sentiment(polarity=-0.023809523809523808, subjectivity=0.023809523809523808)
# negative
# Sentiment(polarity=0.019047619047619042, subjectivity=0.65)
# positive
# Sentiment(polarity=0.08009259259259258, subjectivity=0.43777777777777777)
# positive
# Sentiment(polarity=0.13658008658008658, subjectivity=0.5911255411255412)
# positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# Sentiment(polarity=0.33999999999999997, subjectivity=0.68)
# positive
# Sentiment(polarity=0.16759259259259263, subjectivity=0.5240740740740741)
# positive
# Sentiment(polarity=0.04999999999999997, subjectivity=0.5)
# positive
# Sentiment(polarity=-0.14416666666666664, subjectivity=0.4691666666666666)
# negative
# Sentiment(polarity=-0.3857142857142857, subjectivity=0.5666666666666667)
# negative
# Sentiment(polarity=0.45, subjectivity=0.7)
# positive
# Sentiment(polarity=0.06743589743589742, subjectivity=0.4466666666666667)
# positive
# Sentiment(polarity=-0.697767857142857, subjectivity=0.6714285714285714)
# negative
# Sentiment(polarity=-0.09583333333333333, subjectivity=0.7333333333333334)
# negative
# Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# positive
# Sentiment(polarity=-0.07083333333333335, subjectivity=0.42916666666666664)
# negative
# Sentiment(polarity=-0.15, subjectivity=0.1)
# negative
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
# Sentiment(polarity=0.001190476190476214, subjectivity=0.525)
# positive
# Sentiment(polarity=-0.21874999999999994, subjectivity=0.41666666666666663)
# negative
# Sentiment(polarity=0.022222222222222213, subjectivity=0.34444444444444444)
# positive
# Sentiment(polarity=-0.06299999999999999, subjectivity=0.4862738095238094)
# negative
# Sentiment(polarity=0.07222222222222222, subjectivity=0.4203703703703704)
# positive
# Sentiment(polarity=0.029761904761904767, subjectivity=0.24571428571428575)
# positive
# Sentiment(polarity=0.08854669140383428, subjectivity=0.5935188620902906)
# positive
# Sentiment(polarity=-0.0815814393939394, subjectivity=0.5002840909090909)
# negative
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral

# %%
positive
# negative
# neutral
# Out:
# 33469

# %%
negative
# Out:
# 17941

# %%
neutral
# Out:
# 2356

# %%
rev
# Out:
# ['neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  ...]

# %%
df
# Out:
#          D_id         drugName  ... usefulCount  review.1
# 0         d10      Mirtazapine  ...          22  positive
# 1         d11       Mesalamine  ...          17  positive
# 2         d12          Bactrim  ...           3  positive
# 3         d13         Contrave  ...          35  positive
# 4         d14  Cyclafem 1 / 35  ...           4  positive
# ...       ...              ...  ...         ...       ...
# 53761  d53771        Tamoxifen  ...          43  positive
# 53762  d53772     Escitalopram  ...          11  positive
# 53763  d53773   Levonorgestrel  ...           7  positive
# 53764  d53774       Tapentadol  ...          20  negative
# 53765  d53775        Arthrotec  ...          46  positive
#
# [53766 rows x 8 columns]

# %%
df["reviewtyp"]=rev
df
# Out:
#          D_id         drugName  ...  review.1 reviewtyp
# 0         d10      Mirtazapine  ...  positive   neutral
# 1         d11       Mesalamine  ...  positive  positive
# 2         d12          Bactrim  ...  positive  positive
# 3         d13         Contrave  ...  positive  positive
# 4         d14  Cyclafem 1 / 35  ...  positive  positive
# ...       ...              ...  ...       ...       ...
# 53761  d53771        Tamoxifen  ...  positive  positive
# 53762  d53772     Escitalopram  ...  positive  positive
# 53763  d53773   Levonorgestrel  ...  positive  negative
# 53764  d53774       Tapentadol  ...  negative   neutral
# 53765  d53775        Arthrotec  ...  positive   neutral
#
# [53766 rows x 9 columns]

# %%
df.to_csv('review.csv', encoding='utf-8')

# %%
plt.xlabel("Drugname")
plt.ylabel("review")
plt.pie([positive,negative,neutral],labels=["positive","negative","neutral"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f48c0c5a710>,
#   <matplotlib.patches.Wedge at 0x7f48c0c5a1d0>,
#   <matplotlib.patches.Wedge at 0x7f48c0c57ad0>],
#  [Text(-0.41293709005320656, 1.0195503713198235, 'positive'),
#   Text(0.26911881106163077, -1.0665716410690724, 'negative'),
#   Text(1.0895933035634557, -0.150951756629975, 'neutral')])
